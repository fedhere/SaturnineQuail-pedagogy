# %% [markdown]
# # FDSFE Assignment 6 Instructions
#
# ### Due Date: 11:59pm Monday November 3rd, 2025
#
# To submit, share this notebook to <fortino@udel.edu> and give edit permissions.
#
# ### Getting Started
#
# In order to start working on this assignment you must go to `File` -> `Save a copy in Drive`. Then, you can edit and rename the new copy of this notebook which you will submit.
#
# ### Naming Conventions
# Your submission notebook must follow specific name conventions:
#
# * The name of the file is `FDSFE_Assignment_06.ipynb`.
# * When you make a copy of it, the new file will be named `Copy of FDSFE_Assignment_06.ipynb`.
# * You will rename this file in the following fashion:
#     * First you will include the first letter of your first name, capitalized
#     * Next you will include your surname, also capitalized.
#     * Finally you will include an underscore followed by the original name of the assignment.
#
# For example: My first name is Willow and my last name is Fortino, so I would rename the first assignment as `WFORTINO_FDSFE_Assignment_06.ipynb`.
#
# ### Collaboration and AI Use Statements
#
# The first cell after the instructions in your assignment submission must always be a text cell containing your Collaboration Statement and AI Use Statement.
#
# ### Code Completion Instructions
#
# In some tasks in these assignments you will be given some pre-written code that is incomplete. You will be required to fill in the missing code. In these cases, you will see the following placeholder code:
#
# ```
# # YOUR CODE HERE
# raise NotImplementedError()
# ```
#
# You will delete this and replace it with your own code which completes the task.

# %% [markdown]
# # Collaboration Statement
#
# Who did you work with on this assignment, and what did each of you do?
#
# Your response here:
#
#
# # AI Use
#
# Did you use generative AI (like ChatGPT, Google Gemini, etc.)? What did you use it for? Be specific.
#
# Your response here:

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/FoxFortino/FDSFE_WFortino/refs/heads/main/marketing_campaign.csv", sep="\t")

# %% [markdown]
# # (1 pt) Task 1: Data exploration

# %% [markdown]
# # (1pt) Task 2: Create a restricted dataset that includes only the columns that contain numbers.

# %% [markdown]
# # (1pt) Task 3: Remove all columns that have fewer than fifty unique values.

# %% [markdown]
# # (1pt) Task 4: Remove the ID column.

# %% [markdown]
# # (1pt) Task 5: Replace the the `Year_Birth` column with an `age` column.

# %% [markdown]
# # (1pt) Task 6: Deal with missing values in the dataset.

# %% [markdown]
# # (1pt) Task 7: Scale the data so that each feature has mean zero and standard deviation one.

# %% [markdown]
# # (1pt) Task 8: Plot histograms of all variables. Include a thorough figure caption.

# %% [markdown]
# Figure Caption:

# %% [markdown]
# # (1pt) Task 9: Plot a scatter matrix of all variables. Include a thorough figure caption.

# %% [markdown]
# Figure Caption:

# %% [markdown]
# # (2pt) Task 10: Cluster the data with [dbscan](https://scikit-learn.org/stable/modules/generated/sklearn.cluster.DBSCAN.html). Report how many clusters you find and how many objects are in each cluster.

# %% [markdown]
# # (3pt) Task 11: For each feature create a figure with a histogram for each cluster.
#
# For example, if you found 3 clusters with dbscan, then for each feature you would plot 3 separate histograms (on the same axis) showing the distribution of each feature for each cluster.

# %% [markdown]
# # (1pt) Task 11: Visualize the clusters with [t-SNE](https://scikit-learn.org/stable/modules/generated/sklearn.manifold.TSNE.html). Include a thorough figure caption explaining what t-SNE is and what the plot is showing.
#
# We did not go over t-SNE in class.
