# %%
import numpy as np
from scipy import stats

# %%
stats.poisson.pmf([0, 1, 2, 3, 4], 3).sum()
# Out:
# np.float64(0.8152632445237721)

# %%
stats.poisson.pmf([0, 5], 3)
# Out:
# array([0.04978707, 0.10081881])

# %%
stats.poisson.pmf([4], 2)
# Out:
# array([0.09022352])

# %%
stats.poisson.cdf(4,3)
# Out:
# np.float64(0.8152632445237722)

# %%
stats.norm.pdf(, 0, 1)
# Out:
# np.float64(0.3989422804014327)
