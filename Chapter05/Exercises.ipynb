# %% [markdown]
# # FDSFE Assignment 3 Instructions
#
# ### Due Date: 11:59pm Monday October 13th, 2025
#
# To submit, share this notebook to <fortino@udel.edu> and give edit permissions.
#
# ### Getting Started
#
# In order to start working on this assignment you must go to `File` -> `Save a copy in Drive`. Then, you can edit and rename the new copy of this notebook which you will submit.
#
# ### Naming Conventions
# Your submission notebook must follow specific name conventions:
#
# * The name of the file is `FDSFE_Assignment_03.ipynb`.
# * When you make a copy of it, the new file will be named `Copy of FDSFE_Assignment_03.ipynb`.
# * You will rename this file in the following fashion:
#     * First you will include the first letter of your first name, capitalized
#     * Next you will include your surname, also capitalized.
#     * Finally you will include an underscore followed by the original name of the assignment.
#
# For example: My first name is Willow and my last name is Fortino, so I would rename the first assignment as `WFORTINO_FDSFE_Assignment_03.ipynb`.
#
# ### Collaboration and AI Use Statements
#
# The first cell after the instructions in your assignment submission must always be a text cell containing your Collaboration Statement and AI Use Statement.
#
# ### Code Completion Instructions
#
# In some tasks in these assignments you will be given some pre-written code that is incomplete. You will be required to fill in the missing code. In these cases, you will see the following placeholder code:
#
# ```
# # YOUR CODE HERE
# raise NotImplementedError()
# ```
#
# You will delete this and replace it with your own code which completes the task.

# %% [markdown]
# # Collaboration Statement
#
# Who did you work with on this assignment, and what did each of you do?
#
#
# # AI Use
#
# Did you use generative AI (like ChatGPT, Google Gemini, etc.)? What did you use it for? Be specific.

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import missingno as msno

# %%
df = pd.read_csv("https://raw.githubusercontent.com/fedhere/FDSFE_FBianco/refs/heads/main/StudentPerformanceFactors_modified.csv")

# %% [markdown]
# # Task 1 (1 point): Data Exploration and Visualization
#
# - Perform some exploratory data analysis on the dataset `df`.
# - Write a paragraph summarizing the contents of the dataset and explaining the potential use of the dataset.

# %%
# YOUR DATA EXPLORATION CODE HERE

# %% [markdown]
# [WRITE YOUR RESPONSE HERE]

# %% [markdown]
# # Task 2 (1 point): Restrict
#
# - Generate a restricted dataset from `df` that includes only the numerical features.
# - Use the `.info()` method to prove that the new restricted dataset contains only numerical features.

# %%
# YOUR CODE HERE

# %% [markdown]
# # Task 3 (1 point): Investigate Missing Values
#
# - Use the function `matrix` from the package [`missingno`](https://github.com/ResidentMario/missingno) on the restricted dataset.
# - Read the documentation for the `missingno` package. Provide a figure caption to the figure that the `matrix` function makes explaining what is being shown and why it's important.
# - Remove the rows from the restricted dataset corresponding to the missing values. Use the [`.dropna()`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.dropna.html) method of the Pandas DataFrame.

# %%
# YOUR CODE HERE

# %% [markdown]
# [WRITE YOUR FIGURE CAPTION HERE]

# %% [markdown]
# # Task 4 (1 point): Report Lost Data
#
# - Using `print`, report on how much data was lost, as a percentage, when removing the rows with missing values.

# %%
# YOUR CODE HERE

# %% [markdown]
# # Task 5 (1 point): Correlation
#
# - Using the `.corr()` method of the Pandas DataFrame, generate a correlation matrix.
# - Using [`imshow`](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.imshow.html) from matplotlib, plot the correlation matrix.
# - Ensure that the figure has appropriate axes and ticklabels (see [`ax.set_xticks`](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.set_xticks.html) and [`ax.set_yticks`](https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.axes.Axes.set_yticks.html)).
# - Write a thorough figure caption describing what the figure is. Describe any strong correlations you see.

# %%
# YOUR CODE HERE

# %% [markdown]
# [WRITE YOUR FIGURE CAPTION HERE]

# %% [markdown]
# # Task 6 (2 points): Linear Model
#
# - Make a linear regression model to predict the `Exam_Score` column in the dataset. Only use one feature, the feature that is most highly correlated with `Exam_Score`.
# - Show a scatter plot of the predicted `Exam_Score` against the true `Exam_score`. On this plot, include some measure of the model's performance. Ensure that the figure is clear and contains all relevant information.
# - Write a thorough figure caption describing what the figure is. Describe any shortcomings or strengths of the model.

# %%
# YOUR CODE HERE

# %% [markdown]
# [WRITE YOUR FIGURE CAPTION HERE]

# %% [markdown]
# # Task 7 (2 points): Multiple Linear Regression
#
# - Make a multilinear regression model to predict `Exam_Score`. Include all of the features in the dataset.
# - Using `print`, report the performance of the model using the same metric you used for the linear model in Task 6.

# %%
# YOUR CODE HERE

# %% [markdown]
# # Task 8 (1 point): Comparison
#
# - Compare the performance of the linear model and the multilinear model. Does the performance get better when you include more features? Why or why not?
