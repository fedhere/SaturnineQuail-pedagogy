# %% [markdown]
# # Lesson 1: Python 101

# %% [markdown]
# ## Arithmetic
#
# How to add, subtract, multiply, divide, exponentiate and modulo.

# %%
5 + 5  # Addition
# Out:
# 10

# %%
5 - 5  # Subtraction
# Out:
# 0

# %%
5 * 5  # Multiplication
# Out:
# 25

# %%
5 / 5  # Division
# Out:
# 1.0

# %%
5 ** 2  # Exponentiation
# Out:
# 25

# %%
5 % 5  # Modulo
# Out:
# 0

# %% [markdown]
# ## Hello World
#
# Output the words "Hello World!" to the 'console'.
#
# **Key Ideas:**
# - What is `print`?
# - What is a `type`?
# - What is a string?
# - Single, double and triple quotes?
# - What is a function and what are the parentheses used for?

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# ## Control
#
# Make a decision based on conditions. See [here](https://docs.python.org/3/library/operator.html#mapping-operators-to-functions) for a list of some operators in Python.
#
# **Key Ideas:**
# - The `if` `else` and `elif` statements.
# - What is "white space"?
# - What is a "statement"?
# - `True` and `False`: the *boolean* variables. (Aside: Who is [George Bool](https://en.wikipedia.org/wiki/George_Boole)?)
# - Comparitive operators: Comparing quantities
#     - Less than: `<`
#     - Greater than: `>`
#     - Equality: `==`
#     - Less than or equal to: `>=`
#     - Greater than or equal to: `<=`
#     - Not equal: `!=`
# - Logical operators: Comparing booleans
#     - AND operator: `and` or `&`
#     - OR operator: `or` or `|`
#     - Inversion operator: `not` or `~`

# %% [markdown]
# ### 1. Determine which flour is the cheapest using code. Use the `print` function to say what brand we should buy.

# %%
price_of_flour_brand_A = 6  # Flour from brand A costs this much.
price_of_flour_brand_B = 15  # Flour from brand B costs this much.

# %%
if price_of_flour_brand_A > price_of_flour_brand_B:
    print("Flour brand B is the cheapest.")

elif price_of_flour_brand_A < price_of_flour_brand_B:
    print("Flour brand A is the cheapest.")

else:
    print("Flour brand A and flour brand B are the same price.")
# Out:
# Flour brand A is the cheapest.

# %% [markdown]
# ### 2. What does the `if` and `elif` statements *do*?
#
# Whatever is in front of an `if` or `elif` statement must be a boolean (*i.e.*, `True` or `False`). If the piece of code next to an `if` statement evaluates to `True`, then the indented piece of code is executed. If it evaluates to `False` then the indented code is skipped until the next `elif` statement.

# %%
price_of_flour_brand_A > price_of_flour_brand_B
# Out:
# False

# %% [markdown]
# ### 3. Determine which flour to purchase. You prefer flour from brand B, but you only have so much money.

# %%
spending_money = 9  # I have this much money to spend on flour.

# %%
if price_of_flour_brand_B <= spending_money:
    print("I can buy flour from brand B!")
elif price_of_flour_brand_B > spending_money:
    print("I cannot buy flour from brand B...")

    if price_of_flour_brand_A <= spending_money:
        print("I will buy flour from brand A.")
    else:
        print("I cannot buy any flour.")
# Out:
# I cannot buy flour from brand B...
# I will buy flour from brand A.

# %% [markdown]
# ### 4. Determine which flour to purchase. I still prefer flour from brand B, but brand A *might* have a buy-one-get-one-free deal. If it does, then I will buy from brand A.

# %%
brand_A_deal = True

if (brand_A_deal) and (price_of_flour_brand_A <= spending_money):  # Check if brand A deal is active and if we can afford brand A.
    print("I am buying brand A because they have a deal on!")

elif price_of_flour_brand_B <= spending_money:  # Check if we can afford brand B
    print("I am buying from brand B.")

else:
    print("I cannot afford brand B, and either brand A does not have a deal on or I cannot afford it.")
# Out:
# I am buying brand A because they have a deal on!

# %% [markdown]
# ## Loops
#
# The different types of looping in Python.
#
# **Key Ideas:**
# - The `for` loop.
# - The `continue` and `break` statements.
# - The `while` loop.

# %% [markdown]
# ### Loops Exercise: Fibonacci Sequence
#
# Generate some digits in the Fibonacci sequence starting with `(0, 1)`.

# %% [markdown]
# ## Iterators
#
# The different data structures that Python has for storing sequential information.
#
# **Key Ideas:**
# - Iterables: lists, tuples, strings and sets.
# - Some "methods" of iterables.
# - List comprehensions.

# %% [markdown]
# ### Iterator Exercise
#
# <p>If we list all the natural numbers below $10$ that are multiples of $3$ or $5$, we get $3, 5, 6$ and $9$. The sum of these multiples is $23$.</p>
# <p>Find the sum of all the multiples of $3$ or $5$ below $1000$.</p>

# %%
numbers = [x for x in range(1000) if (x % 3 == 0) or (x % 5 == 0)]
print(sum(numbers))
# Out:
# 233168

# %% [markdown]
# ## Dictionaries
#
# How and when to use dictionaries.
#
# **Key Ideas:**
# - key, value pairs
# - Dictionary comprehensions.

# %% [markdown]
# ## Functions
#
# How to define a function and what are its components.
#
# **Key Ideas:**
# - Defining a function, giving it a name.
# - Function arguments and keyword arguments.
# - The `return` statement.

# %% [markdown]
# ### Functions Exercise
#
# <p>The sum of the squares of the first ten natural numbers is,</p>
# $$1^2 + 2^2 + ... + 10^2 = 385.$$
# <p>The square of the sum of the first ten natural numbers is,</p>
# $$(1 + 2 + ... + 10)^2 = 55^2 = 3025.$$
# <p>Hence the difference between the sum of the squares of the first ten natural numbers and the square of the sum is $3025 - 385 = 2640$.</p>
# <p>Find the difference between the sum of the squares of the first one hundred natural numbers and the square of the sum.</p>

# %%
def sum_squares(n):
    squares = [x**2 for x in range(1, n+1)]
    return sum(squares)

def square_sum(n):
    nums = [x for x in range(1, n+1)]
    return sum(nums)**2

def sum_square_difference(n):
    x = square_sum(n)
    y = sum_squares(n)
    return x - y

print(sum_square_difference(100))
# Out:
# 25164150

# %% [markdown]
# ## Modules
#
# Modules are pre-packaged bundles of code that we can 'import' and use with our own code.
#
# **Key Ideas:**
# - The `import` statement
# - Why do we give nicknames for imported modules?
# - `NumPy`, the package that we will use the most in this course.
# - `matplotlib`, a package we will use to visualize data.

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
sumlist = [1, 2]
evenlist = []

while True:
    a1 = sumlist[-2]
    a2 = sumlist[-1]
    an = a1 + a2

    if an <= 4_000_000:
        sumlist.append(an)
    else:
        break

evenlist = filter(lambda x: x % 2 == 0, sumlist)

print(sum(evenlist))
# Out:
# 4613732
