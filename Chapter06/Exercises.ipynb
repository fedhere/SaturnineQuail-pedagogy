# %% [markdown]
# # FDSFE Assignment 4 Instructions
#
# ### Due Date: 11:59pm Monday October 20th, 2025
#
# To submit, share this notebook to <fortino@udel.edu> and give edit permissions.
#
# ### Getting Started
#
# In order to start working on this assignment you must go to `File` -> `Save a copy in Drive`. Then, you can edit and rename the new copy of this notebook which you will submit.
#
# ### Naming Conventions
# Your submission notebook must follow specific name conventions:
#
# * The name of the file is `FDSFE_Assignment_04.ipynb`.
# * When you make a copy of it, the new file will be named `Copy of FDSFE_Assignment_04.ipynb`.
# * You will rename this file in the following fashion:
#     * First you will include the first letter of your first name, capitalized
#     * Next you will include your surname, also capitalized.
#     * Finally you will include an underscore followed by the original name of the assignment.
#
# For example: My first name is Willow and my last name is Fortino, so I would rename the first assignment as `WFORTINO_FDSFE_Assignment_04.ipynb`.
#
# ### Collaboration and AI Use Statements
#
# The first cell after the instructions in your assignment submission must always be a text cell containing your Collaboration Statement and AI Use Statement.
#
# ### Code Completion Instructions
#
# In some tasks in these assignments you will be given some pre-written code that is incomplete. You will be required to fill in the missing code. In these cases, you will see the following placeholder code:
#
# ```
# # YOUR CODE HERE
# raise NotImplementedError()
# ```
#
# You will delete this and replace it with your own code which completes the task.

# %% [markdown]
# # Collaboration Statement
#
# Who did you work with on this assignment, and what did each of you do?
#
# Your response here:
#
#
# # AI Use
#
# Did you use generative AI (like ChatGPT, Google Gemini, etc.)? What did you use it for? Be specific.
#
# Your response here:

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("https://github.com/fedhere/FDSfE_FBianco/raw/main/data/bank_term_deposit.csv")

# %% [markdown]
# # The Data
#
# https://archive.ics.uci.edu/ml/datasets/bank+marketing#
#
# S. Moro, P. Cortez and P. Rita. A Data-Driven Approach to Predict the Success of Bank Telemarketing. Decision Support Systems, Elsevier, 62:22-31, June 2014
#
# Data Set Information:
#
# The data is related with direct marketing campaigns of a Portuguese banking institution. The marketing campaigns were based on phone calls. Often, more than one contact to the same client was required, in order to figure out if the product (bank term deposit) would be ('yes') or not ('no') subscribed.
#
# # The variable that we want to predict has two possible values:
# - yes -> client subscribed
# - no -> client did not subscribe
#
# ### Features:
# 1. `age`: age of client
# 2. `job`: job type of client
# 3. `marital`: marital status of client
# 4. `education`: highest education level of client
# 5. `default`: whether or not the client is in default
# 6. `balance`: account balance of client
# 7. `housing`: whether or not the client has a housing loan
# 8. `loan`: whether or not the client has a personal loan
# 9. `contact`: contact communication type
# 10. `day`:  last contact day of the week
# 11. `month`: last contact month of year
# 12. `duration`: last contact duration, in seconds
# 13. `campaign`: number of contacts performed during this campaign and for this client
# 14. `pdays`: number of days that passed by after the client was last contacted from a previous campaign (999 means client was not previously contacted)
# 15. `previous`: number of contacts performed before this campaign and for this client
# 16. `poutcome`: outcome of the previous marketing campaign
#
# ### Target
# - `y`: has the client subscribed a term deposit?

# %% [markdown]
# # Task 1 (1 point): Data Exploration and Visualization
#
# - Perform some exploratory data analysis on the dataset `df`.
# - Algorithmically print out each feature name, what data type that feature is and, if it's a categorical variable, what its categories are.

# %%
# YOUR CODE HERE

# %% [markdown]
# # Task 2 (1 point): Restrict
#
# - Generate a restricted dataset from `df` without the following columns:
#     - `day`
#     - `month`
#     - `duration`
#     - `campiagn`
#     - `pdays`
#     - `poutcome`
# - Use the `.info()` method to prove that the new restricted dataset contains the correct features.

# %%
# YOUR CODE HERE

# %% [markdown]
# # Task 3 (1 point): One-Hot Encoding
#
# - One-Hot encode the categorical variables.
# - Use the `.info()` method to prove that the dataset now contains the One-Hot encoded features.

# %%
# YOUR CODE HERE

# %% [markdown]
# # Task 4 (1 point): Preprocess the target variable
#
# - The column `y` is our target. It contains "no" and "yes". Change "no" to 0 and "yes" to 1. Remove the column from the dataframe and store it in a separate variabel called "Y"

# %%
# YOUR CODE HERE

# %% [markdown]
# # Task 5 (1 point): Train-Test Split
#
# - Split the dataset into a training and a testing set.

# %%
# YOUR CODE HERE

# %% [markdown]
# # Task 6 (1 point): Standardizing
#
# - Use the StandardScaler from sklearn to standardize the training set.

# %%
# YOUR CODE HERE

# %% [markdown]
# # Task 7 (1 points): Logistic Regression Model
#
# - Make a logistic regression model to predict the target variable.

# %%
# YOUR CODE HERE

# %% [markdown]
# # Task 8 (3 point): Results
#
# - Print the following metrics on the training and testing set.
#     - Precision
#     - Recall
#     - F1-Score
#     - Accuracy
# - When calculating the metrics on the testing set, be sure to scale the testing set first.
# - Make and display a confusion matrix for the testing set.
# - Provide a thorough figure cation for the confusion matrix. Comment on the performance.

# %%
# YOUR CODE HERE
