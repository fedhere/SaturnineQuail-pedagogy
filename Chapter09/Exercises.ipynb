# %% [markdown]
# # Grade: / 19

# %% [markdown]
# # FDSFE Assignment 7 Instructions
#
# ### Due Date: 11:59pm Monday November 30th, 2025
#
# To submit, share this notebook to <fortino@udel.edu> and give edit permissions.
#
# ### Getting Started
#
# In order to start working on this assignment you must go to `File` -> `Save a copy in Drive`. Then, you can edit and rename the new copy of this notebook which you will submit.
#
# ### Naming Conventions
# Your submission notebook must follow specific name conventions:
#
# * The name of the file is `FDSFE_Assignment_07.ipynb`.
# * When you make a copy of it, the new file will be named `Copy of FDSFE_Assignment_07.ipynb`.
# * You will rename this file in the following fashion:
#     * First you will include the first letter of your first name, capitalized
#     * Next you will include your surname, also capitalized.
#     * Finally you will include an underscore followed by the original name of the assignment.
#
# For example: My first name is Willow and my last name is Fortino, so I would rename the first assignment as `WFORTINO_FDSFE_Assignment_07.ipynb`.
#
# ### Collaboration and AI Use Statements
#
# The first cell after the instructions in your assignment submission must always be a text cell containing your Collaboration Statement and AI Use Statement.
#
# ### Code Completion Instructions
#
# In some tasks in these assignments you will be given some pre-written code that is incomplete. You will be required to fill in the missing code. In these cases, you will see the following placeholder code:
#
# ```
# # YOUR CODE HERE
# raise NotImplementedError()
# ```
#
# You will delete this and replace it with your own code which completes the task.

# %% [markdown]
# # Collaboration Statement
#
# Who did you work with on this assignment, and what did each of you do?
#
# Your response here:
#
#
# # AI Use
#
# Did you use generative AI (like ChatGPT, Google Gemini, etc.)? What did you use it for? Be specific.
#
# Your response here:

# %%
import numpy as np
from matplotlib import pyplot as plt
import keras

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.fashion_mnist.load_data()

# %% [markdown]
# # (2 pt) Task 1: Data exploration
#
# The function below will plot nine images from the Fashion MNIST dataset (either `x_train` or `x_test`). Complete the function.
#
# - Ensure that there are no axis labels, axis ticks or tick labels.
# - Ensure that each image is plotted in black and white.
# - Ensure that each image is easy to see.
# - Ensure that the nine images are plotted in a 3x3 grid.
# - Write a figure caption.

# %%
def plot_images(images):
    fig, axes = plt.subplots


    return fig

fig = plot_images(x_train)
fig.show()

# %% [markdown]
# ### Figure caption:

# %% [markdown]
# # (1 pt) Task 2: Reshape data
#
# We will be creating a CNN. The Conv2D layers require the data to be of shape (`num_samples`, 28, 28, 1). Reshape `x_train` and `x_test` to this.

# %% [markdown]
# # (1 pt) Task 3: Scale data
#
# What is the minimum value of the images? What is the maximum value of the images?
#
# Scale the images so that all pixel values are between 0 and 1.

# %% [markdown]
# # (4 pt) Task 4: Create the CNN
#
# Create a CNN with at least 2 Conv2D layers. Define the loss function, the optimizer, the learning rate, and any metrics.

# %% [markdown]
# # (3 pt) Task 5: Hyperparameter justification
#
# Explain your choice of the follow hyperparameters:
#
# 1. How many convolutional layers did you use and why?
# 2. How many filters does each of your convolutional layers have and why?
# 3. What activation function did you use for your convolutional layers and why?
# 4. How many neurons does your final layer have and why?
# 5. What activation function does your final layer have and why?
# 6. What loss function did you use and why?
# 7. What optimizer did you use and why?
# 8. What learning rate did you use and why?

# %% [markdown]
# ### Answers here:
#
# 1.
# 2.
# 3.
# 4.
# 5.
# 6.
# 7.
# 8.

# %% [markdown]
# # (5 pt) Task 6: Create a confusion matrix for the predictions of the model on the testing set.
#
# - There are 10 classes in the dataset, so the confusion matrix should be 10x10.
# - Plot correct predictions in shades of blue and incorrect predictions in shades of red.
# - Ensure that each cell in the confusion matrix is legible. You may have to tweak the color of the text depending on the color of the cell in the background.
# - Ensure that all axis tick labels are legible.
# - Ensure that all axis labels are legible.
#
# Write a figure caption that explains the results of the model thoroughly.

# %% [markdown]
# ### Figure caption:

# %% [markdown]
# # (3 pt) Task 6: Extract 3 filter weights from each Conv2D layer in your model and plot them. Explain what you see.
#
# We did not go over how to extract weights from models in class, you will have to research this.

# %% [markdown]
# ### Figure caption:
